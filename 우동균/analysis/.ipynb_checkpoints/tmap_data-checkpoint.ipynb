# %%
# %matplotlib inline
import pandas as pd

# %%
tmap = pd.read_csv('../data/Tmap_2005.csv')

# %%
tmap
# Out:
#               일자 지역(시도)  지역(시군구)             검색지명 검색지유형1  검색지유형2    검색지유형3  \
# 0       20200510     강원      삼척시            쏠비치삼척  여행/레저      숙박    콘도/리조트
# 1       20200510     강원      삼척시   삼척해양레일바이크용화정거장  여행/레저  레저/스포츠  레저/스포츠기타
# 2       20200510     강원      삼척시              장호항   교통편의    교통시설        항구
# 3       20200510     강원      삼척시   삼척해양레일바이크궁촌정거장  여행/레저  레저/스포츠  레저/스포츠기타
# 4       20200510     강원      삼척시            해신당공원  여행/레저    관광명소        공원
# ...          ...    ...      ...              ...    ...     ...       ...
# 232495  20200503     충북  청주시 청원구        초정약수세종스파텔  여행/레저    관광명소        온천
# 232496  20200503     충북  청주시 청원구       더휴센트럴파크아파트  건물/시설    주요건물     아파트단지
# 232497  20200503     충북  청주시 청원구       오창대성베르힐아파트  건물/시설    주요건물     아파트단지
# 232498  20200503     충북  청주시 청원구  오창모아미래도와이드시티아파트  건물/시설    주요건물     아파트단지
# 232499  20200503     충북  청주시 청원구            신화아파트  건물/시설    주요건물     아파트단지
#
#         검색지랭킹(시군구내)
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ...             ...
# 232495           26
# 232496           27
# 232497           28
# 232498           29
# 232499           30
#
# [232500 rows x 8 columns]

# %%
tmap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232500 entries, 0 to 232499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   일자           232500 non-null  int64
#  1   지역(시도)       232500 non-null  object
#  2   지역(시군구)      232500 non-null  object
#  3   검색지명         232500 non-null  object
#  4   검색지유형1       232500 non-null  object
#  5   검색지유형2       232500 non-null  object
#  6   검색지유형3       232500 non-null  object
#  7   검색지랭킹(시군구내)  232500 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 8.9+ MB

# %% [markdown]
# # 서울지역만 하는 경우

# %%
c1 = tmap['지역(시도)'] == '서울'
# c2 = tmap['일자']==20200510
seoul = tmap.loc[c1,:]
seoul
# Out:
#               일자 지역(시도) 지역(시군구)           검색지명 검색지유형1 검색지유형2  검색지유형3  \
# 1140    20200510     서울     강동구  고덕래미안힐스테이트아파트  건물/시설   주요건물  아파트브랜드
# 1141    20200510     서울     강동구            천호역   교통편의   교통시설    지하철역
# 1142    20200510     서울     강동구      고덕그라시움아파트  건물/시설   주요건물   아파트단지
# 1143    20200510     서울     강동구       현대백화점천호점     쇼핑  대형유통점     백화점
# 1144    20200510     서울     강동구   강동롯데캐슬퍼스트아파트  건물/시설   주요건물  아파트브랜드
# ...          ...    ...     ...            ...    ...    ...     ...
# 232285  20200503     서울    서대문구   홍제센트럴아이파크아파트  건물/시설   주요건물  아파트브랜드
# 232286  20200503     서울    서대문구        홍제한양아파트  건물/시설   주요건물   아파트단지
# 232287  20200503     서울    서대문구    래미안남가좌2차아파트  건물/시설   주요건물  아파트브랜드
# 232288  20200503     서울    서대문구       북한산더샵아파트  건물/시설   주요건물  아파트브랜드
# 232289  20200503     서울    서대문구  E편한세상신촌2단지아파트  건물/시설   주요건물  아파트브랜드
#
#         검색지랭킹(시군구내)
# 1140              1
# 1141              2
# 1142              3
# 1143              4
# 1144              5
# ...             ...
# 232285           26
# 232286           27
# 232287           28
# 232288           29
# 232289           30
#
# [23250 rows x 8 columns]

# %% [raw]
# cnt_seoul = seoul['검색지명'].value_counts()
# cnt_seoul

# %%
type(cnt_seoul)
data = {'name':[], 'count':[]}
for idx, i in enumerate(cnt_seoul.index):
    if cnt_seoul[idx]<=20: break
    data['name'].append(i)
    data['count'].append(cnt_seoul[idx])
data
cnt_df = pd.DataFrame(data)
cnt_df.head(30)
# 음 한달동안 서울에서 20회 이하는 삭제했을때
# Out:
#                name  count
# 0               서울역     42
# 1             건대입구역     38
# 2            북서울꿈의숲     36
# 3            어린이대공원     33
# 4               천호역     33
# 5            이마트성수점     31
# 6        래미안퍼스티지아파트     31
# 7               불광역     31
# 8            신현대아파트     31
# 9        사당우성2단지아파트     31
# 10              대림역     31
# 11   갤러리아백화점명품관EAST     31
# 12           서울아산병원     31
# 13          국립서울현충원     31
# 14              개봉역     31
# 15       현대시티아울렛가산점     31
# 16               W몰     31
# 17  힐스테이트상도센트럴파크아파트     31
# 18            태릉입구역     31
# 19           이마트상봉점     31
# 20            인수중학교     31
# 21          동대문종합시장     31
# 22           삼성서울병원     31
# 23          롯데월드잠실점     31
# 24          중계그린아파트     31
# 25      신내우디안1단지아파트     31
# 26       꿈의숲롯데캐슬아파트     31
# 27            서대문구청     31
# 28          롯데백화점본점     31
# 29      경희궁자이2단지아파트     31

# %%
# cnt_df.plot(kind='bar')

# %% [markdown]
# # 전체지역

# %%
cnt_tmap = tmap['검색지명'].value_counts()
cnt_tmap
# Out:
# 솔내음         95
# 목월빵집        93
# 수림정         93
# 하우스베이커리     93
# 이성당         93
#             ..
# 마리면사무소       1
# 죽곡면사무소       1
# 충북공업고등학교     1
# 황제능이버섯백숙     1
# 대중순대전문       1
# Name: 검색지명, Length: 16307, dtype: int64
